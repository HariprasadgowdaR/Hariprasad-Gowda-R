# %%
import numpy as np
print("Enter monthly rainfall data:")
rainfall_data = []
for i in range(12):
    while True:
        try:
            rain = int(input(f"Enter rainfall for month {i+1} (mm): "))
            rainfall_data.append(rain)
            break
        except ValueError:
            print("Invalid input. Please enter a whole number.")
print("New monthly rainfall data entered:", rainfall_data)

print("Enter monthly yield data:")
new_yield_data = []
for i in range(12):
    while True:
        try:
            yield_val = float(input(f"Enter yield for month {i+1} (tons/ha): "))
            new_yield_data.append(yield_val)
            break
        except ValueError:
            print("Invalid input. Please enter a number.")
print("New monthly yield data entered:", new_yield_data)

print("RAINFALL STATISTICS")
print(f'Mean: {np.mean(rainfall_data):.2f} mm')
print(f'Median:{np.median(rainfall_data):.2f} mm')
print(f'Std Deviation:{np.std(rainfall_data):.2f} mm')
print(f'Varience:{np.var(rainfall_data):.2f} mm')
print(f'Minimum: {np.min(rainfall_data):.2f} mm (Month{np.argmin(rainfall_data)+1})')
print(f'Maximum: {np.max(rainfall_data):.2f} mm (Month{np.argmax(rainfall_data)+1})')
print(f'Range: {np.ptp(rainfall_data): .2f} mm')

print("\nYIELD STATISTICS")
print(f'Mean:{np.mean(new_yield_data):.2f} tons/ha')
print(f'Median:{np.median(new_yield_data):.2f} tons/ha')
print(f'Std Deviation:{np.std(new_yield_data):.2f} tons/ha')

print("\nPERCENILES")
percentile=[12,50,75,100]
rainfall_percentile=np.percentile(rainfall_data,percentile)
for p, val in zip(percentile,rainfall_percentile):
    print(f'{p}th percentile rainfall: {val:.2f} mm')

print("\nCORRELATION ANALYSIS")
correlation_matrix=np.corrcoef(rainfall_data,new_yield_data)
correlation=correlation_matrix[0,1]
print('Interception: Strong Positive Correlation' if correlation>0.7 else ('Moderate Correlation' if correlation>0.4 else 'Weak correlation'))

print("\nCUMULATIVE RAINFALL")
cumsum=np.cumsum(rainfall_data)
print('Month\trainfall\tcumulative')
for month,(rain,cum) in enumerate (zip(rainfall_data,cumsum),1):
  print(f'{month}\t{rain}\t{cum}')


import matplotlib.pyplot as plt

months = range(1, len(cumsum)+1) # Update months to match the length of rainfall data
plt.figure(figsize=(10, 6))
plt.plot(months, cumsum, marker='o', linestyle='--')
plt.title('Cumulative Rainfall Over Months')
plt.xlabel('Month')
plt.ylabel('Cumulative Rainfall (mm)')
plt.xticks(months)
plt.grid(True)
plt.show()

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(x=rainfall_data, y=new_yield_data)
plt.title('Rainfall vs. Crop Yield')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Yields (tons/ha)')
plt.show()
# Out:
# Enter monthly rainfall data:
# Enter rainfall for month 1 (mm): 110
# Enter rainfall for month 2 (mm): 120
# Enter rainfall for month 3 (mm): 123
# Enter rainfall for month 4 (mm): 134
# Enter rainfall for month 5 (mm): 166
# Enter rainfall for month 6 (mm): 167
# Enter rainfall for month 7 (mm): 180
# Enter rainfall for month 8 (mm): 198
# Enter rainfall for month 9 (mm): 221
# Enter rainfall for month 10 (mm): 150
# Enter rainfall for month 11 (mm): 121
# Enter rainfall for month 12 (mm): 96
# New monthly rainfall data entered: [110, 120, 123, 134, 166, 167, 180, 198, 221, 150, 121, 96]
# Enter monthly yield data:
# Enter yield for month 1 (tons/ha): 11.3
# Enter yield for month 2 (tons/ha): 12.4
# Enter yield for month 3 (tons/ha): 9.98
# Enter yield for month 4 (tons/ha): 10.3
# Enter yield for month 5 (tons/ha): 13.9
# Enter yield for month 6 (tons/ha): 14.6
# Enter yield for month 7 (tons/ha): 15.3
# Enter yield for month 8 (tons/ha): 14.9
# Enter yield for month 9 (tons/ha): 16.97
# Enter yield for month 10 (tons/ha): 11.3
# Enter yield for month 11 (tons/ha): 13.4
# Enter yield for month 12 (tons/ha): 11.2
# New monthly yield data entered: [11.3, 12.4, 9.98, 10.3, 13.9, 14.6, 15.3, 14.9, 16.97, 11.3, 13.4, 11.2]
# RAINFALL STATISTICS
# Mean: 148.83 mm
# Median:142.00 mm
# Std Deviation:36.53 mm
# Varience:1334.64 mm
# Minimum: 96.00 mm (Month12)
# Maximum: 221.00 mm (Month9)
# Range:  125.00 mm
#
# YIELD STATISTICS
# Mean:12.96 tons/ha
# Median:12.90 tons/ha
# Std Deviation:2.12 tons/ha
#
# PERCENILES
# 12th percentile rainfall: 113.20 mm
# 50th percentile rainfall: 142.00 mm
# 75th percentile rainfall: 170.25 mm
# 100th percentile rainfall: 221.00 mm
#
# CORRELATION ANALYSIS
# Interception: Strong Positive Correlation
#
# CUMULATIVE RAINFALL
# Month	rainfall	cumulative
# 1	110	110
# 2	120	230
# 3	123	353
# 4	134	487
# 5	166	653
# 6	167	820
# 7	180	1000
# 8	198	1198
# 9	221	1419
# 10	150	1569
# 11	121	1690
# 12	96	1786
