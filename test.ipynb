# %%
def hari(x,li=[]):
  for i in range(x):
    li.append(i*i)
  print(li)

hari(3,[3,2,1])
# Out:
# [3, 2, 1, 0, 1, 4]

# %%
var=10
for i in range(10):
  for j in range(2,10,1):
    if var%2==0:
      continue
    else:
      var+=1
print(var)
# Out:
# 10

# %%
a=[]
a.append([1,[2,3],4])
print(a)
a.extend([7,8,9])
print(a)
print(a[0][1][1]+a[2])
# Out:
# [[1, [2, 3], 4]]
# [[1, [2, 3], 4], 7, 8, 9]
# 11

# %%
li=[1,1.33,'GFG',0,'No',None,'G',True]
val1,val2=0,''
for x in li:
  if(type(x)==int or type(x)==float):
    val1+=x
  elif(type(x)==str):
    val2+=x
  else:
    break
print(val1,val2)
# Out:
# 2.33 GFGNo

# %%
a=[1,2,3,None,(1,2,3,4,5),['Geeks','for','Geeeks']]
print(len(a))
# Out:
# 6

# %%
nameList=['Harsh','Pratik','Bob','Dhruv']
pos=nameList.index("GeeksforGeeks")
print(pos*3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2437012076.py in <cell line: 0>()
#       1 nameList=['Harsh','Pratik','Bob','Dhruv']
# ----> 2 pos=nameList.index("GeeksforGeeks")
#       3 print(pos*3)
#
# ValueError: 'GeeksforGeeks' is not in list

# %%
li=[1,2,3,4]
li.append([5,6,7,8])
print(li)
# Out:
# [1, 2, 3, 4, [5, 6, 7, 8]]

# %%
a=[1,2,3,4]
b=a
c=a.copy()
d=a
a[0]=[5]
print(a,b,c,d)
# Out:
# [[5], 2, 3, 4] [[5], 2, 3, 4] [1, 2, 3, 4] [[5], 2, 3, 4]

# %%
while True:
  print("Geeks!")
  break
# Out:
# Geeks!

# %%
a=[1,2,3,4]
b=a
b[0]=0;
print(a)
# Out:
# [0, 2, 3, 4]

# %%
x='GFG'
for i in range(x):
  print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4200404923.py in <cell line: 0>()
#       1 x='GFG'
# ----> 2 for i in range(x):
#       3   print(i)
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
num=10
while num>=0:
  if num%2==0:
    print(num)
  num-=1
# Out:
# 10
# 8
# 6
# 4
# 2
# 0

# %%
a=[10,20,30,40,50]
b=[1,2,3,4,5]

subtracted=list()
for a,b in zip(a,b):
  subtracted.append(a-b)
print(subtracted)
# Out:
# [9, 18, 27, 36, 45]

# %%
def addToList(a):
  a+=[10]
b=[10,20,30,40]
addToList(b)
print(b)
print(len(b))
# Out:
# [10, 20, 30, 40, 10]
# 5

# %%
i=1
while True:
  if i%7==0:
    break
  print(i)
  i+=1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
a=['physics','chemistrty',1997,2000]
print(a[1][-1])
# Out:
# y

# %%
li=[1,3,5,7,9]
print(li.pop(-3),end='')

print(li)
# Out:
# 5[1, 3, 7, 9]

# %%
a='Geeks 2256 for 445 Geeks'
b=[x for x in (int(x) for x in a if x.isdigit()) if x%2==0]
print(b)
# Out:
# [2, 2, 6, 4, 4]

# %%
a=['Geks', 'for', 'Geeks']
b=[i[0].upper() for i in a]
print(b)
# Out:
# ['G', 'F', 'G']

# %%
li=range(100,110)
print(li.index(105))
# Out:
# 5

# %%
a=[1998,2002]
b=[2014,2016]
print((a+b)*2)
# Out:
# [1998, 2002, 2014, 2016, 1998, 2002, 2014, 2016]

# %%
def REVERSE(a):
  a.reverse()
  return(a)
def YKNJS(a):
  b=[]
  b.extend(REVERSE(a))
  print(b)

a=[2,6,9,8]
YKNJS(a)
# Out:
# [8, 9, 6, 2]

# %%
for num in range(10,14):
  for i in range (2,num):
    if num%i==1:
      print(num)
      break
# Out:
# 10
# 11
# 12
# 13

# %%
count=0
while count<3:
  print("hello")
  count+=1
else:
  print("Else back")
# Out:
# hello
# hello
# hello
# Else back

# %%
x='abcd'
for i in range(len(x)):
  print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
li=['a','b','c','d','e']
print(li[10:])
# Out:
# []

# %%
while True:
  print("Geeks")
  #break
# Out:
# Geeks

# %%
a=[x for x in range(5)]
b=[x for x in range(7) if x in a and x%2==0]
print(b)
# Out:
# [0, 2, 4]

# %%
li=['Harsh','Pratik','Bob','dhruv']
print(li[1][-1])
# Out:
# k
