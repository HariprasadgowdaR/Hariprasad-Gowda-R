# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({
    'Name':["Alice","Bob","David","Charles","Evn","Frank"],
    'Department':["HR","IT","IT","Finance","HR","Finance"],
    'Salary':[50000,70000,70000,60000,52000,60000],
    'Experience':[2,5,4,6,3,6]
})
print(df)
# Out:
#       Name Department  Salary  Experience
# 0    Alice         HR   50000           2
# 1      Bob         IT   70000           5
# 2    David         IT   70000           4
# 3  Charles    Finance   60000           6
# 4      Evn         HR   52000           3
# 5    Frank    Finance   60000           6

# %%
sal=df.sort_values('Salary')
print(sal)
# Out:
#       Name Department  Salary  Experience
# 0    Alice         HR   50000           2
# 4      Evn         HR   52000           3
# 5    Frank    Finance   60000           6
# 3  Charles    Finance   60000           6
# 2    David         IT   70000           4
# 1      Bob         IT   70000           5

# %%
sal=df.sort_values('Salary',ascending=False)
print(sal)
# Out:
#       Name Department  Salary  Experience
# 1      Bob         IT   70000           5
# 2    David         IT   70000           4
# 5    Frank    Finance   60000           6
# 3  Charles    Finance   60000           6
# 4      Evn         HR   52000           3
# 0    Alice         HR   50000           2

# %%
sal=df.sort_values('Experience',ascending=True)
print(sal)
# Out:
#       Name Department  Salary  Experience
# 0    Alice         HR   50000           2
# 4      Evn         HR   52000           3
# 2    David         IT   70000           4
# 1      Bob         IT   70000           5
# 3  Charles    Finance   60000           6
# 5    Frank    Finance   60000           6

# %%
sal=df.sort_values(['Salary','Experience'],ascending=[False,True])
print(sal)
# Out:
#       Name Department  Salary  Experience
# 2    David         IT   70000           4
# 1      Bob         IT   70000           5
# 3  Charles    Finance   60000           6
# 5    Frank    Finance   60000           6
# 4      Evn         HR   52000           3
# 0    Alice         HR   50000           2

# %%
sal=df.sort_values(['Salary','Experience'])
print(sal)
# Out:
#       Name Department  Salary  Experience
# 0    Alice         HR   50000           2
# 4      Evn         HR   52000           3
# 3  Charles    Finance   60000           6
# 5    Frank    Finance   60000           6
# 2    David         IT   70000           4
# 1      Bob         IT   70000           5

# %%
des=df.sort_index(ascending=False)
print(des)
# Out:
#       Name Department  Salary  Experience
# 5    Frank    Finance   60000           6
# 4      Evn         HR   52000           3
# 3  Charles    Finance   60000           6
# 2    David         IT   70000           4
# 1      Bob         IT   70000           5
# 0    Alice         HR   50000           2

# %%
df['rank_salary']=df['Salary'].rank()
print(df)
# Out:
#       Name Department  Salary  Experience  rank_salary
# 0    Alice         HR   50000           2          1.0
# 1      Bob         IT   70000           5          5.5
# 2    David         IT   70000           4          5.5
# 3  Charles    Finance   60000           6          3.5
# 4      Evn         HR   52000           3          2.0
# 5    Frank    Finance   60000           6          3.5

# %%
df['rank_salary']=df['Salary'].rank(ascending=False)
print(df)
# Out:
#       Name Department  Salary  Experience  rank_salary
# 0    Alice         HR   50000           2          6.0
# 1      Bob         IT   70000           5          1.5
# 2    David         IT   70000           4          1.5
# 3  Charles    Finance   60000           6          3.5
# 4      Evn         HR   52000           3          5.0
# 5    Frank    Finance   60000           6          3.5

# %%
#Dense Ranking
df['dense_rank_salary']=df['Salary'].rank(ascending=False,method='dense')
print(df)
# Out:
#       Name Department  Salary  Experience  rank_salary  dense_rank_salary
# 0    Alice         HR   50000           2          6.0                4.0
# 1      Bob         IT   70000           5          1.5                1.0
# 2    David         IT   70000           4          1.5                1.0
# 3  Charles    Finance   60000           6          3.5                2.0
# 4      Evn         HR   52000           3          5.0                3.0
# 5    Frank    Finance   60000           6          3.5                2.0

# %%
df=df['Department'].value_counts()
print(df)
# Out:
# Department
# HR         2
# IT         2
# Finance    2
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({
    'Name':["Alice","Bob","David","Charles","Evn","Frank"],
    'Department':["HR","IT","IT","Finance","HR","Finance"],
    'Salary':[50000,70000,70000,60000,52000,60000],
    'Experience':[2,5,4,6,3,6]
})

df=df['Department'].value_counts(normalize=True)
print(df)
# Out:
# Department
# HR         0.333333
# IT         0.333333
# Finance    0.333333
# Name: proportion, dtype: float64

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({
    'Name':["Alice","Bob","David","Charles","Evn","Frank"],
    'Department':["HR","IT","IT","Finance","HR","Finance"],
    'Salary':[50000,70000,70000,60000,52000,60000],
    'Experience':[2,5,4,6,3,6]
})

df[['Salary','Experience']].plot()
plt.show()

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({
    'Name':["Alice","Bob","David","Charles","Evn","Frank"],
    'Department':["HR","IT","IT","Finance","HR","Finance"],
    'Salary':[50000,70000,70000,60000,52000,60000],
    'Experience':[2,5,4,6,3,6]
})
df.plot(kind='bar',x='Name',y='Salary')
plt.show()

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({
    'Name':["Alice","Bob","David","Charles","Evn","Frank"],
    'Department':["HR","IT","IT","Finance","HR","Finance"],
    'Salary':[50000,70000,70000,60000,52000,60000],
    'Experience':[2,5,4,6,3,6]
})
df['Salary'].plot(kind='hist',bins=5)
plt.show()

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({
    'Name':["Alice","Bob","David","Charles","Evn","Frank"],
    'Department':["HR","IT","IT","Finance","HR","Finance"],
    'Salary':[50000,70000,70000,60000,52000,60000],
    'Experience':[2,5,4,6,3,6]
})
df.plot(kind='scatter',x='Experience',y='Salary')
plt.show()

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({
    'Name':["Alice","Bob","David","Charles","Evn","Frank"],
    'Department':["HR","IT","IT","Finance","HR","Finance"],
    'Salary':[50000,70000,70000,60000,52000,60000],
    'Experience':[2,5,4,6,3,6]
})
df[['Salary','Experience']].plot(kind='box')
plt.show()
